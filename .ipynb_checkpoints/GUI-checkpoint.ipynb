# %% [markdown]
# !git add .
# !git commit -m filedialogimprovement
# !git push

# %%
import sys
from PyQt5.QtCore import *
from PyQt5.QtGui import *
from PyQt5.QtWidgets import *
import PyQt5
import pandas as pd
data = pd.read_csv("t.csv")

class CustomDialog(QFileDialog):

    def __init__(self, *args, **kwargs):
        super(CustomDialog, self).__init__(*args, **kwargs)

        self.setWindowTitle("HELLOOOOOOOOO!")

        QBtn = QDialogButtonBox.Ok | QDialogButtonBox.Cancel

        self.buttonBox = QDialogButtonBox(QBtn)
        self.buttonBox.accepted.connect(self.accept)
        self.buttonBox.rejected.connect(self.reject)

        self.layout = QVBoxLayout()
        self.layout.addWidget(self.buttonBox)
        self.setLayout(self.layout)

class filedialogdemo(QWidget):
    def __init__(self, parent = None):

        super(filedialogdemo, self).__init__(parent)

        layout = QVBoxLayout()

        self.Browse = QPushButton("Browse")
        self.Browse.clicked.connect(self.getfiles)

        layout.addWidget(self.Browse)
        
        self.table=QLabel()
        self.table.setAlignment(Qt.AlignCenter)

        #self.table.setPixmap(QPixmap("table.png"))
        layout.addWidget(self.table)


        self.setLayout(layout)
        self.setWindowTitle("Exam Scheduleur")

    def getfiles(self, s):
        dlg = CustomDialog(self)
        print(dlg.getOpenFileName()[0])
        self.table.setPixmap(QPixmap("table.png"))


def main():

    app = QApplication(sys.argv)
    ex = filedialogdemo()
    ex.setGeometry(500,500,650,450)

    ex.show()
    sys.exit(app.exec_())

if __name__ == '__main__':
    main()
# Out:
# QWidget::setLayout: Attempting to set QLayout "" on CustomDialog "QFileDialog", which already has a layout
# /home/mgama1/Desktop/ExamsScheduler/table.html
# QWidget::setLayout: Attempting to set QLayout "" on CustomDialog "QFileDialog", which already has a layout
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0
# /home/mgama1/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3441: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
# table export as image , excel, html
import numpy as np
import pandas as pd
import dataframe_image as dfi
df = pd.read_csv("t.csv")

def setBackgroundColor(data):
    s = data.index % 2 != 0
    s = pd.concat([pd.Series(s)] * data.shape[1], axis=1) #6 or the n of cols u have
    z = pd.DataFrame(np.where(s, 'background-color:#104A60;color:white;', 'background-color:#ffffff;color:black;'),
                 index=data.index, columns=data.columns)
    z2 = pd.DataFrame(np.where(s, 'color:#000000', 'color:#ffffff'),
                 index=data.index, columns=data.columns)
    return z

dfstyled=df.style.apply(setBackgroundColor,axis=None)

dfi.export(dfstyled, 'table.png')

dfstyled
# Out:
# [0118/060059.481475:WARNING:sandbox_linux.cc(380)] InitializeSandbox() called with multiple threads in process gpu-process.
# [0118/060059.533988:WARNING:bluez_dbus_manager.cc(247)] Floss manager not present, cannot set Floss enable/disable.
# [0118/060059.705596:INFO:headless_shell.cc(623)] Written to file /tmp/tmpa686zym_/temp.png.
# <style type="text/css">
# #T_1afb8_row0_col0, #T_1afb8_row0_col1, #T_1afb8_row0_col2, #T_1afb8_row0_col3, #T_1afb8_row2_col0, #T_1afb8_row2_col1, #T_1afb8_row2_col2, #T_1afb8_row2_col3, #T_1afb8_row4_col0, #T_1afb8_row4_col1, #T_1afb8_row4_col2, #T_1afb8_row4_col3, #T_1afb8_row6_col0, #T_1afb8_row6_col1, #T_1afb8_row6_col2, #T_1afb8_row6_col3, #T_1afb8_row8_col0, #T_1afb8_row8_col1, #T_1afb8_row8_col2, #T_1afb8_row8_col3, #T_1afb8_row10_col0, #T_1afb8_row10_col1, #T_1afb8_row10_col2, #T_1afb8_row10_col3, #T_1afb8_row12_col0, #T_1afb8_row12_col1, #T_1afb8_row12_col2, #T_1afb8_row12_col3, #T_1afb8_row14_col0, #T_1afb8_row14_col1, #T_1afb8_row14_col2, #T_1afb8_row14_col3 {
#   background-color: #ffffff;
#   color: black;
# }
# #T_1afb8_row1_col0, #T_1afb8_row1_col1, #T_1afb8_row1_col2, #T_1afb8_row1_col3, #T_1afb8_row3_col0, #T_1afb8_row3_col1, #T_1afb8_row3_col2, #T_1afb8_row3_col3, #T_1afb8_row5_col0, #T_1afb8_row5_col1, #T_1afb8_row5_col2, #T_1afb8_row5_col3, #T_1afb8_row7_col0, #T_1afb8_row7_col1, #T_1afb8_row7_col2, #T_1afb8_row7_col3, #T_1afb8_row9_col0, #T_1afb8_row9_col1, #T_1afb8_row9_col2, #T_1afb8_row9_col3, #T_1afb8_row11_col0, #T_1afb8_row11_col1, #T_1afb8_row11_col2, #T_1afb8_row11_col3, #T_1afb8_row13_col0, #T_1afb8_row13_col1, #T_1afb8_row13_col2, #T_1afb8_row13_col3, #T_1afb8_row15_col0, #T_1afb8_row15_col1, #T_1afb8_row15_col2, #T_1afb8_row15_col3 {
#   background-color: #104A60;
#   color: white;
# }
# </style>
# <table id="T_1afb8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1afb8_level0_col0" class="col_heading level0 col0" >Unnamed: 0</th>
#       <th id="T_1afb8_level0_col1" class="col_heading level0 col1" >course1</th>
#       <th id="T_1afb8_level0_col2" class="col_heading level0 col2" >course2</th>
#       <th id="T_1afb8_level0_col3" class="col_heading level0 col3" >course3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1afb8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1afb8_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_1afb8_row0_col1" class="data row0 col1" >FundOfMangement</td>
#       <td id="T_1afb8_row0_col2" class="data row0 col2" >accounting</td>
#       <td id="T_1afb8_row0_col3" class="data row0 col3" >PLC</td>
#     </tr>
#     <tr>
#       <th id="T_1afb8_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_1afb8_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_1afb8_row1_col1" class="data row1 col1" >Control1</td>
#       <td id="T_1afb8_row1_col2" class="data row1 col2" >AVS</td>
#       <td id="T_1afb8_row1_col3" class="data row1 col3" >MechanicsAndThermodynamics</td>
#     </tr>
#     <tr>
#       <th id="T_1afb8_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_1afb8_row2_col0" class="data row2 col0" >2</td>
#       <td id="T_1afb8_row2_col1" class="data row2 col1" >Ethics</td>
#       <td id="T_1afb8_row2_col2" class="data row2 col2" >-</td>
#       <td id="T_1afb8_row2_col3" class="data row2 col3" >-</td>
#     </tr>
#     <tr>
#       <th id="T_1afb8_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_1afb8_row3_col0" class="data row3 col0" >3</td>
#       <td id="T_1afb8_row3_col1" class="data row3 col1" >MachineDesign2</td>
#       <td id="T_1afb8_row3_col2" class="data row3 col2" >Physics</td>
#       <td id="T_1afb8_row3_col3" class="data row3 col3" >-</td>
#     </tr>
#     <tr>
#       <th id="T_1afb8_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_1afb8_row4_col0" class="data row4 col0" >4</td>
#       <td id="T_1afb8_row4_col1" class="data row4 col1" >TechnicalWriting</td>
#       <td id="T_1afb8_row4_col2" class="data row4 col2" >-</td>
#       <td id="T_1afb8_row4_col3" class="data row4 col3" >-</td>
#     </tr>
#     <tr>
#       <th id="T_1afb8_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_1afb8_row5_col0" class="data row5 col0" >5</td>
#       <td id="T_1afb8_row5_col1" class="data row5 col1" >Vibration</td>
#       <td id="T_1afb8_row5_col2" class="data row5 col2" >-</td>
#       <td id="T_1afb8_row5_col3" class="data row5 col3" >-</td>
#     </tr>
#     <tr>
#       <th id="T_1afb8_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_1afb8_row6_col0" class="data row6 col0" >6</td>
#       <td id="T_1afb8_row6_col1" class="data row6 col1" >Thermodynamics</td>
#       <td id="T_1afb8_row6_col2" class="data row6 col2" >-</td>
#       <td id="T_1afb8_row6_col3" class="data row6 col3" >-</td>
#     </tr>
#     <tr>
#       <th id="T_1afb8_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_1afb8_row7_col0" class="data row7 col0" >7</td>
#       <td id="T_1afb8_row7_col1" class="data row7 col1" >Fields</td>
#       <td id="T_1afb8_row7_col2" class="data row7 col2" >-</td>
#       <td id="T_1afb8_row7_col3" class="data row7 col3" >-</td>
#     </tr>
#     <tr>
#       <th id="T_1afb8_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_1afb8_row8_col0" class="data row8 col0" >8</td>
#       <td id="T_1afb8_row8_col1" class="data row8 col1" >CSAndProgramming</td>
#       <td id="T_1afb8_row8_col2" class="data row8 col2" >InudstrialElectronics</td>
#       <td id="T_1afb8_row8_col3" class="data row8 col3" >FundOfManuf</td>
#     </tr>
#     <tr>
#       <th id="T_1afb8_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_1afb8_row9_col0" class="data row9 col0" >9</td>
#       <td id="T_1afb8_row9_col1" class="data row9 col1" >DigitalControl</td>
#       <td id="T_1afb8_row9_col2" class="data row9 col2" >-</td>
#       <td id="T_1afb8_row9_col3" class="data row9 col3" >-</td>
#     </tr>
#     <tr>
#       <th id="T_1afb8_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_1afb8_row10_col0" class="data row10 col0" >10</td>
#       <td id="T_1afb8_row10_col1" class="data row10 col1" >Electronics1</td>
#       <td id="T_1afb8_row10_col2" class="data row10 col2" >SensorsAndActuators</td>
#       <td id="T_1afb8_row10_col3" class="data row10 col3" >calc1</td>
#     </tr>
#     <tr>
#       <th id="T_1afb8_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_1afb8_row11_col0" class="data row11 col0" >11</td>
#       <td id="T_1afb8_row11_col1" class="data row11 col1" >Mechanics1</td>
#       <td id="T_1afb8_row11_col2" class="data row11 col2" >ManufSystemAutomation</td>
#       <td id="T_1afb8_row11_col3" class="data row11 col3" >Calc3</td>
#     </tr>
#     <tr>
#       <th id="T_1afb8_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_1afb8_row12_col0" class="data row12 col0" >12</td>
#       <td id="T_1afb8_row12_col1" class="data row12 col1" >Robotics</td>
#       <td id="T_1afb8_row12_col2" class="data row12 col2" >Signal</td>
#       <td id="T_1afb8_row12_col3" class="data row12 col3" >Mechatronics1</td>
#     </tr>
#     <tr>
#       <th id="T_1afb8_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_1afb8_row13_col0" class="data row13 col0" >13</td>
#       <td id="T_1afb8_row13_col1" class="data row13 col1" >LinearAlgebra</td>
#       <td id="T_1afb8_row13_col2" class="data row13 col2" >Logic</td>
#       <td id="T_1afb8_row13_col3" class="data row13 col3" >Microcontroller</td>
#     </tr>
#     <tr>
#       <th id="T_1afb8_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_1afb8_row14_col0" class="data row14 col0" >14</td>
#       <td id="T_1afb8_row14_col1" class="data row14 col1" >NumericalControl</td>
#       <td id="T_1afb8_row14_col2" class="data row14 col2" >EngineeringDrawing</td>
#       <td id="T_1afb8_row14_col3" class="data row14 col3" >-</td>
#     </tr>
#     <tr>
#       <th id="T_1afb8_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_1afb8_row15_col0" class="data row15 col0" >15</td>
#       <td id="T_1afb8_row15_col1" class="data row15 col1" >Fluid</td>
#       <td id="T_1afb8_row15_col2" class="data row15 col2" >-</td>
#       <td id="T_1afb8_row15_col3" class="data row15 col3" >-</td>
#     </tr>
#   </tbody>
# </table>

# %%
df.to_excel("table.xlsx")
dfstyled.to_html("table.html")

# %%
import pandas as pd
import numpy as np
import random
import time
import warnings
warnings.filterwarnings("ignore")
class Scheduler():


    
    def __init__(self,courses):
        self.courses= courses 
        self.timeTable=0
        self.students=0
        self.coursesDic2=0

    def MAD(self,x):
        '''
        calculates the median absolute deviation which is defined as median(|x_i - median(x)|
        inputs: arraylike 
              X
        outputs: numpy float
              MAD
        '''
        return np.median(np.absolute(x - np.median(x)))

    def isTaken(self,course):
        '''
        checks whether the courses is already in the time table or not
        inputs: str
              course name
        outputs: bool
               True if exists in the table, False otherwise
        '''
        t1=any(self.timeTable["course1"].astype(str).str.match(course))
        t2=any(self.timeTable["course2"].astype(str).str.match(course))
        t3=any(self.timeTable["course3"].astype(str).str.match(course))

        return t1 or t2 or t3


    def isIntersected(self,*args):
        '''
        checks the intersection of students between two courses
        inputs: str
              course 1 name , course 2 name
        outputs: bool
               True if there is intersection and False otherwise
        '''

        df_merge=pd.concat(list(args))
        isduplicated=df_merge.duplicated()
        return not len(df_merge[isduplicated])==0


    def isInCourse(self,course,M):
        '''
        checks whether stuent M is in course Course or not

        '''

        try:
            return self.coursesDic2[course].loc[self.students.index[M]].count()>0
        except:
            return False

    def getStudentCourses(self,M):
        '''
        returns student M courses

        '''
        studentMCourses=[]
        for course in self.coursesDic2.keys():
            if self.isInCourse(course,M):
                studentMCourses.append(course)
            return studentMCourses



    def studentMMAD(self,M):
        '''
        calculates the MAD of student M's time table

        '''
        studentMTimeTable=self.timeTable[self.timeTable["course1"].astype(str).str.match("|".join(self.getStudentCourses(M))) | 
                          self.timeTable["course2"].astype(str).str.match("|".join(self.getStudentCourses(M))) |
                          self.timeTable["course3"].astype(str).str.match("|".join(self.getStudentCourses(M)))]
        index=studentMTimeTable.index
        return self.MAD(index)   

    def avgMAD(self):
        '''
        calculates avgerage Mad for this particular time table
        '''

        sum=0
        for M in range(len(self.students)):
            sum+=self.studentMMAD(M)

        avg=sum/len(self.students)
        return avg

    
    def getTable(self):
        timeTableList=[]
        for iteration in range(30):
            coursesDic=dict()
            for sheetnum,sheet in enumerate(self.courses.sheet_names):

                # Parse data from each worksheet as a Pandas DataFrame and append it 
                # to the dic
                df = self.courses.parse(sheet)
                df.set_index('name',inplace=True)
                df["name_col"]=df.index
                coursesDic[self.courses.sheet_names[sheetnum]]=df

                self.coursesDic2=coursesDic.copy()


            self.timeTable = pd.DataFrame(data={'course1':[], 'course2': [],'course3':[]})

            for i in range(1000):
                try:
                    randCourseI=random.choice(list(coursesDic.keys()))
                    randCourseJ=random.choice(list(coursesDic.keys()))
                    randCourseK=random.choice(list(coursesDic.keys()))
                except:
                    None

                if(not self.isTaken(randCourseI) and  not self.isTaken(randCourseJ)and  not self.isTaken(randCourseK)):
                    if(self.isIntersected(self.coursesDic2[randCourseI],self.coursesDic2[randCourseJ],self.coursesDic2[randCourseK])==False):


                        dayNCourses = pd.DataFrame([[randCourseI,randCourseJ,randCourseK]],
                                                  columns=self.timeTable.columns)
                        self.timeTable=self.timeTable.append(dayNCourses,ignore_index=True)
                        coursesDic.pop(randCourseI)
                        coursesDic.pop(randCourseJ)
                        coursesDic.pop(randCourseK)



            for i in range(500):
                try:
                    randCourseI=random.choice(list(coursesDic.keys()))
                    randCourseJ=random.choice(list(coursesDic.keys()))
                except:
                    None

                if(not self.isTaken(randCourseI) and  not self.isTaken(randCourseJ)):
                    if(self.isIntersected(self.coursesDic2[randCourseI],self.coursesDic2[randCourseJ])==False):


                        dayNCourses = pd.DataFrame([[randCourseI,randCourseJ,"-"]],
                                                  columns=self.timeTable.columns)
                        self.timeTable=self.timeTable.append(dayNCourses,ignore_index=True)
                        coursesDic.pop(randCourseI)
                        coursesDic.pop(randCourseJ)


            for course in list(coursesDic.keys()):

                    coursesDic.pop(course)

                    dayNCourses = pd.DataFrame([[course,"-","-"]],
                                              columns=self.timeTable.columns)
                    self.timeTable=self.timeTable.append(dayNCourses,ignore_index=True)

            timeTableList.append(self.timeTable)

        #Finding the table with minimum number of days 
        for i in range(len(timeTableList)):
            if len(timeTableList[i])<len(self.timeTable):
                self.timeTable=timeTableList[i]

        #Creating a students dataframe from all courses
        self.students=pd.DataFrame(columns=['name'])
        self.students.set_index('name',inplace=True)
        self.students["e"]=0

        for course in self.coursesDic2.values():

            self.students=pd.merge(self.students,course, how='outer',left_index=True, right_index=True).dropna(axis=1)


        #shuffling and choosing the timetable with the maximum 

        #average median absolute deviation
        avgMADList=[]
        timeTableList=[]
        for i in range(100):
            self.timeTable=self.timeTable.sample(frac = 1,ignore_index=True)
            timeTableList.append(self.timeTable)
            avgMADList.append(self.avgMAD())


        maxIndex=avgMADList.index(max(avgMADList))
        self.timeTable=timeTableList[maxIndex]

        return self.timeTable

# %%
Scheduler(pd.ExcelFile("courses.xlsx")).getTable()
# Out:
#                   course1                     course2          course3
# 0      EngineeringDrawing             Microcontroller            Calc3
# 1           Mechatronics1         SensorsAndActuators  FundOfMangement
# 2              Mechanics1       ManufSystemAutomation   Thermodynamics
# 3                Robotics              MachineDesign2          Physics
# 4   InudstrialElectronics                Electronics1            calc1
# 5                Control1                           -                -
# 6        NumericalControl                           -                -
# 7             FundOfManuf                         PLC           Fields
# 8        CSAndProgramming              DigitalControl                -
# 9           LinearAlgebra                      Signal            Fluid
# 10                    AVS  MechanicsAndThermodynamics            Logic
# 11              Vibration                  accounting                -
# 12       TechnicalWriting                           -                -
# 13                 Ethics                           -                -
