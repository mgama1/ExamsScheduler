# %%
# !git add .
# !git commit -m tablecolornative
# !git push
# Out:
# [main 619c25e] tablecolornative
#  5 files changed, 20501 insertions(+), 268 deletions(-)
#  create mode 100644 table.html
#  create mode 100644 table.png
#  create mode 100644 table.xlsx
# Enumerating objects: 12, done.
# Counting objects: 100% (11/11), done.
# Delta compression using up to 4 threads
# Compressing objects: 100% (7/7), done.
# Writing objects: 100% (8/8), 73.19 KiB | 3.18 MiB/s, done.
# Total 8 (delta 1), reused 0 (delta 0)
# remote: Resolving deltas: 100% (1/1), done.
# To https://github.com/mgama1/ExamsScheduler.git
#    a5fac60..619c25e  main -> main

# %%
#file 
import sys
from PyQt5.QtCore import *
from PyQt5.QtGui import *
from PyQt5.QtWidgets import *

class filedialogdemo(QWidget):
    def __init__(self, parent = None):
        super(filedialogdemo, self).__init__(parent)
        layout = QVBoxLayout()
        self.btn = QPushButton("QFileDialog static method demo")
        self.btn.clicked.connect(self.getfile)

        layout.addWidget(self.btn)
        self.le = QLabel("Hello")

        layout.addWidget(self.le)
        self.btn1 = QPushButton("QFileDialog object")
        self.btn1.clicked.connect(self.getfiles)
        layout.addWidget(self.btn1)

        self.contents = QTextEdit()
        layout.addWidget(self.contents)
        self.setLayout(layout)
        self.setWindowTitle("File Dialog demo")

    def getfile(self):
        fname = QFileDialog.getOpenFileName(self, 'Open file', 
         'c:\\',"excel files (*.xls *.xlsx *.txt)")
        self.le.setPixmap(QPixmap(fname))

    def getfiles(self):
        dlg = QFileDialog()
        dlg.setFileMode(QFileDialog.AnyFile)
        dlg.setFilter("Text files (*.txt)")
        filenames = QStringList()

        if dlg.exec_():
            filenames = dlg.selectedFiles()
            f = open(filenames[0], 'r')

            with f:
                data = f.read()
                self.contents.setText(data)

def main():
    app = QApplication(sys.argv)
    ex = filedialogdemo()
    ex.show()
    sys.exit(app.exec_())

if __name__ == '__main__':
    main()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 30, in filedialogdemo.getfile(self)
#      27 def getfile(self):
#      28     fname = QFileDialog.getOpenFileName(self, 'Open file',
#      29      'c:\\',"excel files (*.xls *.xlsx *.txt)")
# ---> 30     self.le.setPixmap(QPixmap(fname))
#
# TypeError: QPixmap(): argument 1 has unexpected type 'tuple'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 35, in filedialogdemo.getfiles(self)
#      33 dlg = QFileDialog()
#      34 dlg.setFileMode(QFileDialog.AnyFile)
# ---> 35 dlg.setFilter("Text files (*.txt)")
#      36 filenames = QStringList()
#      38 if dlg.exec_():
#
# TypeError: setFilter(self, Union[QDir.Filters, QDir.Filter]): argument 1 has unexpected type 'str'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 35, in filedialogdemo.getfiles(self)
#      33 dlg = QFileDialog()
#      34 dlg.setFileMode(QFileDialog.AnyFile)
# ---> 35 dlg.setFilter("Text files (*.txt)")
#      36 filenames = QStringList()
#      38 if dlg.exec_():
#
# TypeError: setFilter(self, Union[QDir.Filters, QDir.Filter]): argument 1 has unexpected type 'str'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 35, in filedialogdemo.getfiles(self)
#      33 dlg = QFileDialog()
#      34 dlg.setFileMode(QFileDialog.AnyFile)
# ---> 35 dlg.setFilter("Text files (*.txt)")
#      36 filenames = QStringList()
#      38 if dlg.exec_():
#
# TypeError: setFilter(self, Union[QDir.Filters, QDir.Filter]): argument 1 has unexpected type 'str'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 35, in filedialogdemo.getfiles(self)
#      33 dlg = QFileDialog()
#      34 dlg.setFileMode(QFileDialog.AnyFile)
# ---> 35 dlg.setFilter("Text files (*.txt)")
#      36 filenames = QStringList()
#      38 if dlg.exec_():
#
# TypeError: setFilter(self, Union[QDir.Filters, QDir.Filter]): argument 1 has unexpected type 'str'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 35, in filedialogdemo.getfiles(self)
#      33 dlg = QFileDialog()
#      34 dlg.setFileMode(QFileDialog.AnyFile)
# ---> 35 dlg.setFilter("Text files (*.txt)")
#      36 filenames = QStringList()
#      38 if dlg.exec_():
#
# TypeError: setFilter(self, Union[QDir.Filters, QDir.Filter]): argument 1 has unexpected type 'str'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 35, in filedialogdemo.getfiles(self)
#      33 dlg = QFileDialog()
#      34 dlg.setFileMode(QFileDialog.AnyFile)
# ---> 35 dlg.setFilter("Text files (*.txt)")
#      36 filenames = QStringList()
#      38 if dlg.exec_():
#
# TypeError: setFilter(self, Union[QDir.Filters, QDir.Filter]): argument 1 has unexpected type 'str'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 35, in filedialogdemo.getfiles(self)
#      33 dlg = QFileDialog()
#      34 dlg.setFileMode(QFileDialog.AnyFile)
# ---> 35 dlg.setFilter("Text files (*.txt)")
#      36 filenames = QStringList()
#      38 if dlg.exec_():
#
# TypeError: setFilter(self, Union[QDir.Filters, QDir.Filter]): argument 1 has unexpected type 'str'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 35, in filedialogdemo.getfiles(self)
#      33 dlg = QFileDialog()
#      34 dlg.setFileMode(QFileDialog.AnyFile)
# ---> 35 dlg.setFilter("Text files (*.txt)")
#      36 filenames = QStringList()
#      38 if dlg.exec_():
#
# TypeError: setFilter(self, Union[QDir.Filters, QDir.Filter]): argument 1 has unexpected type 'str'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 35, in filedialogdemo.getfiles(self)
#      33 dlg = QFileDialog()
#      34 dlg.setFileMode(QFileDialog.AnyFile)
# ---> 35 dlg.setFilter("Text files (*.txt)")
#      36 filenames = QStringList()
#      38 if dlg.exec_():
#
# TypeError: setFilter(self, Union[QDir.Filters, QDir.Filter]): argument 1 has unexpected type 'str'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 35, in filedialogdemo.getfiles(self)
#      33 dlg = QFileDialog()
#      34 dlg.setFileMode(QFileDialog.AnyFile)
# ---> 35 dlg.setFilter("Text files (*.txt)")
#      36 filenames = QStringList()
#      38 if dlg.exec_():
#
# TypeError: setFilter(self, Union[QDir.Filters, QDir.Filter]): argument 1 has unexpected type 'str'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 35, in filedialogdemo.getfiles(self)
#      33 dlg = QFileDialog()
#      34 dlg.setFileMode(QFileDialog.AnyFile)
# ---> 35 dlg.setFilter("Text files (*.txt)")
#      36 filenames = QStringList()
#      38 if dlg.exec_():
#
# TypeError: setFilter(self, Union[QDir.Filters, QDir.Filter]): argument 1 has unexpected type 'str'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 35, in filedialogdemo.getfiles(self)
#      33 dlg = QFileDialog()
#      34 dlg.setFileMode(QFileDialog.AnyFile)
# ---> 35 dlg.setFilter("Text files (*.txt)")
#      36 filenames = QStringList()
#      38 if dlg.exec_():
#
# TypeError: setFilter(self, Union[QDir.Filters, QDir.Filter]): argument 1 has unexpected type 'str'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 35, in filedialogdemo.getfiles(self)
#      33 dlg = QFileDialog()
#      34 dlg.setFileMode(QFileDialog.AnyFile)
# ---> 35 dlg.setFilter("Text files (*.txt)")
#      36 filenames = QStringList()
#      38 if dlg.exec_():
#
# TypeError: setFilter(self, Union[QDir.Filters, QDir.Filter]): argument 1 has unexpected type 'str'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 35, in filedialogdemo.getfiles(self)
#      33 dlg = QFileDialog()
#      34 dlg.setFileMode(QFileDialog.AnyFile)
# ---> 35 dlg.setFilter("Text files (*.txt)")
#      36 filenames = QStringList()
#      38 if dlg.exec_():
#
# TypeError: setFilter(self, Union[QDir.Filters, QDir.Filter]): argument 1 has unexpected type 'str'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 35, in filedialogdemo.getfiles(self)
#      33 dlg = QFileDialog()
#      34 dlg.setFileMode(QFileDialog.AnyFile)
# ---> 35 dlg.setFilter("Text files (*.txt)")
#      36 filenames = QStringList()
#      38 if dlg.exec_():
#
# TypeError: setFilter(self, Union[QDir.Filters, QDir.Filter]): argument 1 has unexpected type 'str'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 35, in filedialogdemo.getfiles(self)
#      33 dlg = QFileDialog()
#      34 dlg.setFileMode(QFileDialog.AnyFile)
# ---> 35 dlg.setFilter("Text files (*.txt)")
#      36 filenames = QStringList()
#      38 if dlg.exec_():
#
# TypeError: setFilter(self, Union[QDir.Filters, QDir.Filter]): argument 1 has unexpected type 'str'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 35, in filedialogdemo.getfiles(self)
#      33 dlg = QFileDialog()
#      34 dlg.setFileMode(QFileDialog.AnyFile)
# ---> 35 dlg.setFilter("Text files (*.txt)")
#      36 filenames = QStringList()
#      38 if dlg.exec_():
#
# TypeError: setFilter(self, Union[QDir.Filters, QDir.Filter]): argument 1 has unexpected type 'str'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 35, in filedialogdemo.getfiles(self)
#      33 dlg = QFileDialog()
#      34 dlg.setFileMode(QFileDialog.AnyFile)
# ---> 35 dlg.setFilter("Text files (*.txt)")
#      36 filenames = QStringList()
#      38 if dlg.exec_():
#
# TypeError: setFilter(self, Union[QDir.Filters, QDir.Filter]): argument 1 has unexpected type 'str'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 35, in filedialogdemo.getfiles(self)
#      33 dlg = QFileDialog()
#      34 dlg.setFileMode(QFileDialog.AnyFile)
# ---> 35 dlg.setFilter("Text files (*.txt)")
#      36 filenames = QStringList()
#      38 if dlg.exec_():
#
# TypeError: setFilter(self, Union[QDir.Filters, QDir.Filter]): argument 1 has unexpected type 'str'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 35, in filedialogdemo.getfiles(self)
#      33 dlg = QFileDialog()
#      34 dlg.setFileMode(QFileDialog.AnyFile)
# ---> 35 dlg.setFilter("Text files (*.txt)")
#      36 filenames = QStringList()
#      38 if dlg.exec_():
#
# TypeError: setFilter(self, Union[QDir.Filters, QDir.Filter]): argument 1 has unexpected type 'str'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 35, in filedialogdemo.getfiles(self)
#      33 dlg = QFileDialog()
#      34 dlg.setFileMode(QFileDialog.AnyFile)
# ---> 35 dlg.setFilter("Text files (*.txt)")
#      36 filenames = QStringList()
#      38 if dlg.exec_():
#
# TypeError: setFilter(self, Union[QDir.Filters, QDir.Filter]): argument 1 has unexpected type 'str'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 35, in filedialogdemo.getfiles(self)
#      33 dlg = QFileDialog()
#      34 dlg.setFileMode(QFileDialog.AnyFile)
# ---> 35 dlg.setFilter("Text files (*.txt)")
#      36 filenames = QStringList()
#      38 if dlg.exec_():
#
# TypeError: setFilter(self, Union[QDir.Filters, QDir.Filter]): argument 1 has unexpected type 'str'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 35, in filedialogdemo.getfiles(self)
#      33 dlg = QFileDialog()
#      34 dlg.setFileMode(QFileDialog.AnyFile)
# ---> 35 dlg.setFilter("Text files (*.txt)")
#      36 filenames = QStringList()
#      38 if dlg.exec_():
#
# TypeError: setFilter(self, Union[QDir.Filters, QDir.Filter]): argument 1 has unexpected type 'str'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 35, in filedialogdemo.getfiles(self)
#      33 dlg = QFileDialog()
#      34 dlg.setFileMode(QFileDialog.AnyFile)
# ---> 35 dlg.setFilter("Text files (*.txt)")
#      36 filenames = QStringList()
#      38 if dlg.exec_():
#
# TypeError: setFilter(self, Union[QDir.Filters, QDir.Filter]): argument 1 has unexpected type 'str'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 35, in filedialogdemo.getfiles(self)
#      33 dlg = QFileDialog()
#      34 dlg.setFileMode(QFileDialog.AnyFile)
# ---> 35 dlg.setFilter("Text files (*.txt)")
#      36 filenames = QStringList()
#      38 if dlg.exec_():
#
# TypeError: setFilter(self, Union[QDir.Filters, QDir.Filter]): argument 1 has unexpected type 'str'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 35, in filedialogdemo.getfiles(self)
#      33 dlg = QFileDialog()
#      34 dlg.setFileMode(QFileDialog.AnyFile)
# ---> 35 dlg.setFilter("Text files (*.txt)")
#      36 filenames = QStringList()
#      38 if dlg.exec_():
#
# TypeError: setFilter(self, Union[QDir.Filters, QDir.Filter]): argument 1 has unexpected type 'str'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 35, in filedialogdemo.getfiles(self)
#      33 dlg = QFileDialog()
#      34 dlg.setFileMode(QFileDialog.AnyFile)
# ---> 35 dlg.setFilter("Text files (*.txt)")
#      36 filenames = QStringList()
#      38 if dlg.exec_():
#
# TypeError: setFilter(self, Union[QDir.Filters, QDir.Filter]): argument 1 has unexpected type 'str'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 35, in filedialogdemo.getfiles(self)
#      33 dlg = QFileDialog()
#      34 dlg.setFileMode(QFileDialog.AnyFile)
# ---> 35 dlg.setFilter("Text files (*.txt)")
#      36 filenames = QStringList()
#      38 if dlg.exec_():
#
# TypeError: setFilter(self, Union[QDir.Filters, QDir.Filter]): argument 1 has unexpected type 'str'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 35, in filedialogdemo.getfiles(self)
#      33 dlg = QFileDialog()
#      34 dlg.setFileMode(QFileDialog.AnyFile)
# ---> 35 dlg.setFilter("Text files (*.txt)")
#      36 filenames = QStringList()
#      38 if dlg.exec_():
#
# TypeError: setFilter(self, Union[QDir.Filters, QDir.Filter]): argument 1 has unexpected type 'str'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 30, in filedialogdemo.getfile(self)
#      27 def getfile(self):
#      28     fname = QFileDialog.getOpenFileName(self, 'Open file',
#      29      'c:\\',"excel files (*.xls *.xlsx *.txt)")
# ---> 30     self.le.setPixmap(QPixmap(fname))
#
# TypeError: QPixmap(): argument 1 has unexpected type 'tuple'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 35, in filedialogdemo.getfiles(self)
#      33 dlg = QFileDialog()
#      34 dlg.setFileMode(QFileDialog.AnyFile)
# ---> 35 dlg.setFilter("Text files (*.txt)")
#      36 filenames = QStringList()
#      38 if dlg.exec_():
#
# TypeError: setFilter(self, Union[QDir.Filters, QDir.Filter]): argument 1 has unexpected type 'str'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 30, in filedialogdemo.getfile(self)
#      27 def getfile(self):
#      28     fname = QFileDialog.getOpenFileName(self, 'Open file',
#      29      'c:\\',"excel files (*.xls *.xlsx *.txt)")
# ---> 30     self.le.setPixmap(QPixmap(fname))
#
# TypeError: QPixmap(): argument 1 has unexpected type 'tuple'
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0

# %%
#table
from PyQt5.QtWidgets import QMainWindow, QApplication, QWidget, QAction, QTableWidget,QTableWidgetItem,QVBoxLayout
from PyQt5.QtGui import QIcon
from PyQt5.QtCore import pyqtSlot
import sys
import PyQt5
import pandas as pd
data = pd.read_csv("t.csv")
 
class TableView(QTableWidget):
    def __init__(self, data, *args):
        QTableWidget.__init__(self, *args)
        self.data = data
        self.setData()
        self.resizeColumnsToContents()
        self.resizeRowsToContents()
        
    def setData(self): 
        horHeaders = []
        for n, key in enumerate(sorted(self.data.keys())):
            horHeaders.append(key)
            for m, item in enumerate(self.data[key]):
                newitem = QTableWidgetItem(item)
                if (m%2==0):
                    
                    newitem.setBackground(PyQt5.QtGui.QColor(16, 74, 96))
                    newitem.setForeground(PyQt5.QtGui.QColor(255, 255, 255))


                self.setItem(m, n, newitem)
        self.setHorizontalHeaderLabels(horHeaders)
        

def main(args):
    app = QApplication(args)
    #app.setStyleSheet("background-color: yellow;")

    table = TableView(data, data.shape[0], data.shape[1])
    table.show()
    sys.exit(app.exec_())
 
if __name__=="__main__":
    main(sys.argv)
# Out:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0
# /home/mgama1/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3441: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
import numpy as np
import pandas as pd
import dataframe_image as dfi
df = pd.read_csv("t.csv")

def setBackgroundColor(data):
    s = data.index % 2 != 0
    s = pd.concat([pd.Series(s)] * data.shape[1], axis=1) #6 or the n of cols u have
    z = pd.DataFrame(np.where(s, 'background-color:#104A60;color:white;', 'background-color:#ffffff;color:black;'),
                 index=data.index, columns=data.columns)
    z2 = pd.DataFrame(np.where(s, 'color:#000000', 'color:#ffffff'),
                 index=data.index, columns=data.columns)
    return z
dfstyled=df.style.apply(setBackgroundColor,axis=None)
dfi.export(dfstyled, 'table.png')
df.to_excel("table.xlsx")
dfstyled.to_html("table.html")
dfstyled
# Out:
# [0111/212314.506953:WARNING:sandbox_linux.cc(380)] InitializeSandbox() called with multiple threads in process gpu-process.
# [0111/212314.630995:WARNING:bluez_dbus_manager.cc(247)] Floss manager not present, cannot set Floss enable/disable.
# [0111/212314.820545:INFO:headless_shell.cc(623)] Written to file /tmp/tmpiuqqenqc/temp.png.
# <style type="text/css">
# #T_a42ee_row0_col0, #T_a42ee_row0_col1, #T_a42ee_row0_col2, #T_a42ee_row0_col3, #T_a42ee_row2_col0, #T_a42ee_row2_col1, #T_a42ee_row2_col2, #T_a42ee_row2_col3, #T_a42ee_row4_col0, #T_a42ee_row4_col1, #T_a42ee_row4_col2, #T_a42ee_row4_col3, #T_a42ee_row6_col0, #T_a42ee_row6_col1, #T_a42ee_row6_col2, #T_a42ee_row6_col3, #T_a42ee_row8_col0, #T_a42ee_row8_col1, #T_a42ee_row8_col2, #T_a42ee_row8_col3, #T_a42ee_row10_col0, #T_a42ee_row10_col1, #T_a42ee_row10_col2, #T_a42ee_row10_col3, #T_a42ee_row12_col0, #T_a42ee_row12_col1, #T_a42ee_row12_col2, #T_a42ee_row12_col3, #T_a42ee_row14_col0, #T_a42ee_row14_col1, #T_a42ee_row14_col2, #T_a42ee_row14_col3 {
#   background-color: #ffffff;
#   color: black;
# }
# #T_a42ee_row1_col0, #T_a42ee_row1_col1, #T_a42ee_row1_col2, #T_a42ee_row1_col3, #T_a42ee_row3_col0, #T_a42ee_row3_col1, #T_a42ee_row3_col2, #T_a42ee_row3_col3, #T_a42ee_row5_col0, #T_a42ee_row5_col1, #T_a42ee_row5_col2, #T_a42ee_row5_col3, #T_a42ee_row7_col0, #T_a42ee_row7_col1, #T_a42ee_row7_col2, #T_a42ee_row7_col3, #T_a42ee_row9_col0, #T_a42ee_row9_col1, #T_a42ee_row9_col2, #T_a42ee_row9_col3, #T_a42ee_row11_col0, #T_a42ee_row11_col1, #T_a42ee_row11_col2, #T_a42ee_row11_col3, #T_a42ee_row13_col0, #T_a42ee_row13_col1, #T_a42ee_row13_col2, #T_a42ee_row13_col3, #T_a42ee_row15_col0, #T_a42ee_row15_col1, #T_a42ee_row15_col2, #T_a42ee_row15_col3 {
#   background-color: #104A60;
#   color: white;
# }
# </style>
# <table id="T_a42ee">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a42ee_level0_col0" class="col_heading level0 col0" >Unnamed: 0</th>
#       <th id="T_a42ee_level0_col1" class="col_heading level0 col1" >course1</th>
#       <th id="T_a42ee_level0_col2" class="col_heading level0 col2" >course2</th>
#       <th id="T_a42ee_level0_col3" class="col_heading level0 col3" >course3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a42ee_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a42ee_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_a42ee_row0_col1" class="data row0 col1" >FundOfMangement</td>
#       <td id="T_a42ee_row0_col2" class="data row0 col2" >accounting</td>
#       <td id="T_a42ee_row0_col3" class="data row0 col3" >PLC</td>
#     </tr>
#     <tr>
#       <th id="T_a42ee_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a42ee_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_a42ee_row1_col1" class="data row1 col1" >Control1</td>
#       <td id="T_a42ee_row1_col2" class="data row1 col2" >AVS</td>
#       <td id="T_a42ee_row1_col3" class="data row1 col3" >MechanicsAndThermodynamics</td>
#     </tr>
#     <tr>
#       <th id="T_a42ee_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a42ee_row2_col0" class="data row2 col0" >2</td>
#       <td id="T_a42ee_row2_col1" class="data row2 col1" >Ethics</td>
#       <td id="T_a42ee_row2_col2" class="data row2 col2" >-</td>
#       <td id="T_a42ee_row2_col3" class="data row2 col3" >-</td>
#     </tr>
#     <tr>
#       <th id="T_a42ee_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a42ee_row3_col0" class="data row3 col0" >3</td>
#       <td id="T_a42ee_row3_col1" class="data row3 col1" >MachineDesign2</td>
#       <td id="T_a42ee_row3_col2" class="data row3 col2" >Physics</td>
#       <td id="T_a42ee_row3_col3" class="data row3 col3" >-</td>
#     </tr>
#     <tr>
#       <th id="T_a42ee_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_a42ee_row4_col0" class="data row4 col0" >4</td>
#       <td id="T_a42ee_row4_col1" class="data row4 col1" >TechnicalWriting</td>
#       <td id="T_a42ee_row4_col2" class="data row4 col2" >-</td>
#       <td id="T_a42ee_row4_col3" class="data row4 col3" >-</td>
#     </tr>
#     <tr>
#       <th id="T_a42ee_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_a42ee_row5_col0" class="data row5 col0" >5</td>
#       <td id="T_a42ee_row5_col1" class="data row5 col1" >Vibration</td>
#       <td id="T_a42ee_row5_col2" class="data row5 col2" >-</td>
#       <td id="T_a42ee_row5_col3" class="data row5 col3" >-</td>
#     </tr>
#     <tr>
#       <th id="T_a42ee_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_a42ee_row6_col0" class="data row6 col0" >6</td>
#       <td id="T_a42ee_row6_col1" class="data row6 col1" >Thermodynamics</td>
#       <td id="T_a42ee_row6_col2" class="data row6 col2" >-</td>
#       <td id="T_a42ee_row6_col3" class="data row6 col3" >-</td>
#     </tr>
#     <tr>
#       <th id="T_a42ee_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_a42ee_row7_col0" class="data row7 col0" >7</td>
#       <td id="T_a42ee_row7_col1" class="data row7 col1" >Fields</td>
#       <td id="T_a42ee_row7_col2" class="data row7 col2" >-</td>
#       <td id="T_a42ee_row7_col3" class="data row7 col3" >-</td>
#     </tr>
#     <tr>
#       <th id="T_a42ee_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_a42ee_row8_col0" class="data row8 col0" >8</td>
#       <td id="T_a42ee_row8_col1" class="data row8 col1" >CSAndProgramming</td>
#       <td id="T_a42ee_row8_col2" class="data row8 col2" >InudstrialElectronics</td>
#       <td id="T_a42ee_row8_col3" class="data row8 col3" >FundOfManuf</td>
#     </tr>
#     <tr>
#       <th id="T_a42ee_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_a42ee_row9_col0" class="data row9 col0" >9</td>
#       <td id="T_a42ee_row9_col1" class="data row9 col1" >DigitalControl</td>
#       <td id="T_a42ee_row9_col2" class="data row9 col2" >-</td>
#       <td id="T_a42ee_row9_col3" class="data row9 col3" >-</td>
#     </tr>
#     <tr>
#       <th id="T_a42ee_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_a42ee_row10_col0" class="data row10 col0" >10</td>
#       <td id="T_a42ee_row10_col1" class="data row10 col1" >Electronics1</td>
#       <td id="T_a42ee_row10_col2" class="data row10 col2" >SensorsAndActuators</td>
#       <td id="T_a42ee_row10_col3" class="data row10 col3" >calc1</td>
#     </tr>
#     <tr>
#       <th id="T_a42ee_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_a42ee_row11_col0" class="data row11 col0" >11</td>
#       <td id="T_a42ee_row11_col1" class="data row11 col1" >Mechanics1</td>
#       <td id="T_a42ee_row11_col2" class="data row11 col2" >ManufSystemAutomation</td>
#       <td id="T_a42ee_row11_col3" class="data row11 col3" >Calc3</td>
#     </tr>
#     <tr>
#       <th id="T_a42ee_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_a42ee_row12_col0" class="data row12 col0" >12</td>
#       <td id="T_a42ee_row12_col1" class="data row12 col1" >Robotics</td>
#       <td id="T_a42ee_row12_col2" class="data row12 col2" >Signal</td>
#       <td id="T_a42ee_row12_col3" class="data row12 col3" >Mechatronics1</td>
#     </tr>
#     <tr>
#       <th id="T_a42ee_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_a42ee_row13_col0" class="data row13 col0" >13</td>
#       <td id="T_a42ee_row13_col1" class="data row13 col1" >LinearAlgebra</td>
#       <td id="T_a42ee_row13_col2" class="data row13 col2" >Logic</td>
#       <td id="T_a42ee_row13_col3" class="data row13 col3" >Microcontroller</td>
#     </tr>
#     <tr>
#       <th id="T_a42ee_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_a42ee_row14_col0" class="data row14 col0" >14</td>
#       <td id="T_a42ee_row14_col1" class="data row14 col1" >NumericalControl</td>
#       <td id="T_a42ee_row14_col2" class="data row14 col2" >EngineeringDrawing</td>
#       <td id="T_a42ee_row14_col3" class="data row14 col3" >-</td>
#     </tr>
#     <tr>
#       <th id="T_a42ee_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_a42ee_row15_col0" class="data row15 col0" >15</td>
#       <td id="T_a42ee_row15_col1" class="data row15 col1" >Fluid</td>
#       <td id="T_a42ee_row15_col2" class="data row15 col2" >-</td>
#       <td id="T_a42ee_row15_col3" class="data row15 col3" >-</td>
#     </tr>
#   </tbody>
# </table>

# %%
import sys
from PyQt5.QtCore import *
from PyQt5.QtGui import *
from PyQt5.QtWidgets import *
class CustomDialog(QFileDialog):

    def __init__(self, *args, **kwargs):
        super(CustomDialog, self).__init__(*args, **kwargs)

        self.setWindowTitle("HELLO!")

        QBtn = QDialogButtonBox.Ok | QDialogButtonBox.Cancel

        self.buttonBox = QDialogButtonBox(QBtn)
        self.buttonBox.accepted.connect(self.accept)
        self.buttonBox.rejected.connect(self.reject)

        self.layout = QVBoxLayout()
        self.layout.addWidget(self.buttonBox)
        self.setLayout(self.layout)

class filedialogdemo(QWidget):
    def __init__(self, parent = None):

        super(filedialogdemo, self).__init__(parent)

        layout = QVBoxLayout()

        self.btn1 = QPushButton("QFileDialog object")
        self.btn1.clicked.connect(self.getfiles)
        layout.addWidget(self.btn1)

        self.contents = QTextEdit()
        layout.addWidget(self.contents)
        self.setLayout(layout)
        self.setWindowTitle("File Dialog demo")

    def getfiles(self, s):
        dlg = CustomDialog(self)
        print(dlg.getOpenFileName())
        if dlg.exec_():
            filenames = dlg.selectedFiles()
            f = open(filenames[0], 'r')

        with f:
            data = f.read()
            self.contents.setText(data)
def main():

    app = QApplication(sys.argv)
    ex = filedialogdemo()
    ex.show()
    sys.exit(app.exec_())

if __name__ == '__main__':
    main()
# Out:
# QWidget::setLayout: Attempting to set QLayout "" on CustomDialog "QFileDialog", which already has a layout
# ('/home/mgama1/Desktop/test.txt', 'All Files (*)')
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[7], line 45, in filedialogdemo.getfiles(self, s)
#      42     filenames = dlg.selectedFiles()
#      43     f = open(filenames[0], 'r')
# ---> 45 with f:
#      46     data = f.read()
#      47     self.contents.setText(data)
#
# UnboundLocalError: local variable 'f' referenced before assignment
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0
